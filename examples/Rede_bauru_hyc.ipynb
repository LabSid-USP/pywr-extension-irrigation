# %%
import os
import sys
import datetime
import pywr
import pandas as pd
from pywr.core import Timestepper
from pywr.core import Model, Input, Output
from pywr.core import *
from pywr.nodes import *
from pywr.recorders import NumpyArrayNodeRecorder, ParameterRecorder, Recorder, NumpyArrayParameterRecorder
from pywr.model import Model
from pywr.nodes import Node, Link, Output

caminho_pai = os.path.dirname(os.getcwd())
if caminho_pai not in sys.path:
    sys.path.append(caminho_pai)

from pywr_ext_irrigation.modules import AquiferWithoutKeatingOutflows
from pywr_ext_irrigation.modules import SoilReservoir
from pywr_ext_irrigation.parameters import Evapotranspiration
from pywr_ext_irrigation.parameters import PreliminarIrrigatedVolume
from pywr_ext_irrigation.parameters import WaterStressCoefficient

mymodel = Model.load("./rede_bauru_fim.json")

mymodel.run()

try:
        r1 = mymodel.nodes["Rsl_1"]
except KeyError:
        print("Not found")
else:
        nam1=(f"name: {r1.name}")
        min_volum1=((r1.min_volume))
        init_vo1=((r1.initial_volume))
        maxvol1=((r1.max_volume))
        uin1=((r1.Uin.get_constant_value()))
        dg1=((r1.dg.get_constant_value()))
        zr1=((r1.Zr.get_constant_value()))
        airr1=((r1.Airr.get_constant_value()))
        wp1=((r1.WP.get_constant_value()))
        fc1=((r1.FC.get_constant_value()))
        
        print(nam1,min_volum1,init_vo1,maxvol1,uin1,dg1,airr1,wp1,fc1)
        
try:
        r2 = mymodel.nodes["Rsl_2"]
except KeyError:
        print("Not found")
else:
        nam2=(f"name: {r2.name}")
        min_volum2=((r2.min_volume))
        init_vo2=((r2.initial_volume))
        maxvol2=((r2.max_volume))
        uin2=((r2.Uin.get_constant_value()))
        dg2=((r2.dg.get_constant_value()))
        zr2=((r2.Zr.get_constant_value()))
        airr2=((r2.Airr.get_constant_value()))
        wp2=((r2.WP.get_constant_value()))
        fc2=((r2.FC.get_constant_value()))
        print(nam2,min_volum2,init_vo2,maxvol2,uin2,dg2,airr2,wp2,fc2)

try:
        r3 = mymodel.nodes["Rsl_3"]
except KeyError:
        print("Not found")
else:
        nam3=(f"name: {r3.name}")
        min_volum3=((r3.min_volume))
        init_vo3=((r3.initial_volume))
        maxvol3=((r3.max_volume))
        uin3=((r3.Uin.get_constant_value()))
        dg3=((r3.dg.get_constant_value()))
        zr3=((r3.Zr.get_constant_value()))
        airr3=((r3.Airr.get_constant_value()))
        wp3=((r3.WP.get_constant_value()))
        fc3=((r3.FC.get_constant_value()))

        print(nam3,min_volum3,init_vo3,maxvol3,uin3,dg3,airr3,wp3,fc3)


try:
        r34 = mymodel.recorders["par1"]
        #r34 = mymodel.recorders["vol2"]
except KeyError:
        print("Not found")
else:
         def22=pd.DataFrame(r34.data)
         print(r34.data)
# Out:
# Error loading component Prev_flow_Rsl_3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 25
#      22 from pywr_ext_irrigation.parameters import PreliminarIrrigatedVolume
#      23 from pywr_ext_irrigation.parameters import WaterStressCoefficient
# ---> 25 mymodel = Model.load("./rede_bauru_fim.json")
#      27 mymodel.run()
#      29 try:
#
# File pywr\\_model.pyx:290, in pywr._model.Model.load()
#
# File pywr\\_model.pyx:208, in pywr._model.Model.loads()
#
# File pywr\\_model.pyx:298, in pywr._model.Model.load()
#
# File pywr\\_model.pyx:424, in pywr._model.Model._load_from_dict()
#
# File pywr\\_model.pyx:1086, in pywr._model.listify.wrapper()
#
# File pywr\\_model.pyx:415, in load_components()
#
# File pywr\\_model.pyx:411, in pywr._model.Model._load_from_dict.load_components()
#
# File pywr\\parameters\\_parameters.pyx:2309, in pywr.parameters._parameters.load_parameter()
#
# File f:\Workspaces\LabSid\pywr-extension-irrigation\pywr_ext_irrigation\parameters\preliminar_irrigated_volume.py:121, in PreliminarIrrigatedVolume.load(cls, model, data)
#     119 @classmethod
#     120 def load(cls, model, data):
# --> 121     Eta = load_parameter(model,data.pop("eta"))
#     122     Prec = load_parameter(model,data.pop("prec"))
#     123     AS = model.nodes[data.pop("AS")]
#
# File pywr\\parameters\\_parameters.pyx:2283, in pywr.parameters._parameters.load_parameter()
#
# File pywr\\parameters\\_parameters.pyx:2309, in pywr.parameters._parameters.load_parameter()
#
# File f:\Workspaces\LabSid\pywr-extension-irrigation\pywr_ext_irrigation\parameters\evapotranspiration.py:60, in Evapotranspiration.load(cls, model, data)
#      58 @classmethod
#      59 def load(cls, model, data):
# ---> 60     Etp = load_parameter(model,data.pop("etp"))
#      61     Kc = load_parameter(model,data.pop("kc"))
#      62     node = model.nodes[data.pop("node")]
#
# File pywr\\parameters\\_parameters.pyx:2283, in pywr.parameters._parameters.load_parameter()
#
# File pywr\\parameters\\_parameters.pyx:2309, in pywr.parameters._parameters.load_parameter()
#
# File pywr\\parameters\\_parameters.pyx:278, in pywr.parameters._parameters.DataFrameParameter.load()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pywr\dataframe_tools.py:178, in load_dataframe(model, data)
#     176 else:
#     177     name = data.get("url", None)
# --> 178     df = read_dataframe(model, data)
#     180 # if column is not specified, use the whole dataframe
#     181 if column is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pywr\dataframe_tools.py:259, in read_dataframe(model, data)
#     256 data.pop("comment", None)  # remove kwargs from data before passing to Pandas
#     258 if filetype == "csv":
# --> 259     df = pandas.read_csv(url, **data)  # automatically decompressed gzipped data!
#     260 elif filetype == "excel":
#     261     df = pandas.read_excel(url, **data)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:162, in CParserWrapper.__init__(self, src, **kwds)
#     160 # error: Cannot determine type of 'names'
#     161 self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
# --> 162 self._set_noconvert_columns()
#     164 # error: Cannot determine type of 'names'
#     165 self.orig_names = self.names  # type: ignore[has-type]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:215, in CParserWrapper._set_noconvert_columns(self)
#     213 col_indices = [names_dict[x] for x in self.names]  # type: ignore[has-type]
#     214 # error: Cannot determine type of 'names'
# --> 215 noconvert_columns = self._set_noconvert_dtype_columns(
#     216     col_indices,
#     217     self.names,  # type: ignore[has-type]
#     218 )
#     219 for col in noconvert_columns:
#     220     self._reader.set_noconvert(col)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\base_parser.py:663, in ParserBase._set_noconvert_dtype_columns(self, col_indices, names)
#     661 if isinstance(self.index_col, list):
#     662     for k in self.index_col:
# --> 663         noconvert_columns.add(_set(k))
#     664 elif self.index_col is not None:
#     665     noconvert_columns.add(_set(self.index_col))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\base_parser.py:640, in ParserBase._set_noconvert_dtype_columns.<locals>._set(x)
#     637     x = usecols[x]
#     639 if not is_integer(x):
# --> 640     x = col_indices[names.index(x)]
#     642 return x
#
# ValueError: 'Date' is not in list
